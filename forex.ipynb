# %%
# !pip install yfinance pandas

# For data manipulation
import numpy as np
import pandas as pd

# To fetch financial data
import yfinance as yf

# For visualisation
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

# Ignore warnings
import warnings 
warnings.filterwarnings('ignore')

# %%
 # similar to equities
 # download the FX price data using the download() method of the yfinance package by passing the proper ticker. 
 # to download the data for EUR/USD, you can pass the respective ticker, EURUSD=X as the ticker parameter in the download method

# Set the ticker as 'EURUSD=X'
forex_data = yf.download('EURUSD=X', start='2019-01-02')

# Set the index to a datetime object
forex_data.index = pd.to_datetime(forex_data.index)

# Display the last five rows
forex_data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open   Volume
# Ticker      EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X EURUSD=X
# Date
# 2025-07-30  1.155095  1.157274  1.145935  1.155095        0
# 2025-07-31  1.142936  1.146027  1.140654  1.142936        0
# 2025-08-01  1.142374  1.158292  1.139458  1.142374        0
# 2025-08-04  1.158668  1.158883  1.155095  1.158668        0
# 2025-08-05  1.154734  1.159152  1.153403  1.157140        0

# %%
# Plot the close price
plt.figure(figsize=(10,7))
forex_data['Close'].plot()

# Set the title and axis label
plt.title('EUR/USD Data', fontsize=14)
plt.xlabel('Year-Month', fontsize=12)
plt.ylabel('Price', fontsize=12)

# Show the plot
plt.show()

# %%
# minute fx pricing data
# Pass the proper ticker, period and interval to the download method of yfinance

# Set the ticker as 'EURUSD=X'
forex_data_minute = yf.download('EURUSD=X', period='5d', interval='1m')

# Set the index to a datetime object
forex_data_minute.index = pd.to_datetime(forex_data_minute.index)

# Display the last five rows
forex_data_minute.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                         Close      High       Low      Open   Volume
# Ticker                     EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X EURUSD=X
# Datetime
# 2025-08-05 10:41:00+00:00  1.154734  1.154734  1.154734  1.154734        0
# 2025-08-05 10:42:00+00:00  1.154734  1.154734  1.154734  1.154734        0
# 2025-08-05 10:43:00+00:00  1.154734  1.154734  1.154734  1.154734        0
# 2025-08-05 10:44:00+00:00  1.154734  1.154734  1.154734  1.154734        0
# 2025-08-05 10:45:00+00:00  1.154868  1.154868  1.154868  1.154868        0

# %%
def format_xlabels(data, ax):
    """This function will format the x-labels of the graph
    """
    num_x_values = data.shape[0]
    step_size = num_x_values // 4    

    ax.set_xticks(np.arange(num_x_values))
    ax.set_xticklabels(data.index.values, rotation=45)
   
    for i, label in enumerate(ax.get_xticklabels()):
        if not i%step_size==0:
            label.set_visible(False)  
    label.set_visible(True)

# %%
# Number of points to plot
x_values = forex_data_minute['Close'].shape[0]

# Plot the series
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(range(x_values), forex_data_minute['Close'])

# Set title and axis label
plt.title('EUR/USD Data', fontsize=14)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Price', fontsize=12)

# Format the xlabel
format_xlabels(forex_data_minute['Close'], ax)

# Show the plot
plt.show()

# %%
# fetching data for EUR/CHF

forex_data_eurchf = yf.download('EURCHF=X', start='2025-07-01')
forex_data_eurchf.index = pd.to_datetime(forex_data_eurchf.index)
forex_data_eurchf.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Close     High      Low     Open   Volume
# Ticker     EURCHF=X EURCHF=X EURCHF=X EURCHF=X EURCHF=X
# Date
# 2025-07-29  0.93147  0.93240  0.92945  0.93147        0
# 2025-07-30  0.93037  0.93147  0.92930  0.93037        0
# 2025-07-31  0.92939  0.93069  0.92842  0.92939        0
# 2025-08-01  0.92966  0.93240  0.92850  0.92966        0
# 2025-08-04  0.93154  0.93586  0.93142  0.93154        0
