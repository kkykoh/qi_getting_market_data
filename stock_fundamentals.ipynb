# %%
# Update to the latest simfin library version
# !pip install --upgrade simfin

# Import the SimFin library
import simfin as sf

# Import the names used for easy access to SimFin's data-columns
from simfin.names import *

# Import time manipulation library
from datetime import timedelta

# Import data manipulation library
import pandas as pd

# Import matplotlib and set the style for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: simfin in c:\users\kaiyi\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas in c:\users\kaiyi\anaconda3\lib\site-packages (from simfin) (2.0.3)
# Requirement already satisfied: numpy in c:\users\kaiyi\anaconda3\lib\site-packages (from simfin) (1.24.3)
# Requirement already satisfied: requests in c:\users\kaiyi\anaconda3\lib\site-packages (from simfin) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kaiyi\anaconda3\lib\site-packages (from pandas->simfin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaiyi\anaconda3\lib\site-packages (from pandas->simfin) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kaiyi\anaconda3\lib\site-packages (from pandas->simfin) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kaiyi\anaconda3\lib\site-packages (from requests->simfin) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaiyi\anaconda3\lib\site-packages (from requests->simfin) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaiyi\anaconda3\lib\site-packages (from requests->simfin) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaiyi\anaconda3\lib\site-packages (from requests->simfin) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\kaiyi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->simfin) (1.16.0)
